# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Задача:-предсказание-уровня-удовлетворённости-сотрудника" data-toc-modified-id="Задача:-предсказание-уровня-удовлетворённости-сотрудника-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Задача: предсказание уровня удовлетворённости сотрудника</a></span><ul class="toc-item"><li><span><a href="#Загрузка-данных" data-toc-modified-id="Загрузка-данных-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Загрузка данных</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#train_job_satisfaction_rate" data-toc-modified-id="train_job_satisfaction_rate-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>train_job_satisfaction_rate</a></span></li><li><span><a href="#test_features" data-toc-modified-id="test_features-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>test_features</a></span></li><li><span><a href="#test_target_job_satisfaction_rate" data-toc-modified-id="test_target_job_satisfaction_rate-1.2.3"><span class="toc-item-num">1.2.3&nbsp;&nbsp;</span>test_target_job_satisfaction_rate</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Отдел,-в-котором-работает-сотрудник-dept" data-toc-modified-id="Отдел,-в-котором-работает-сотрудник-dept-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>Отдел, в котором работает сотрудник <code>dept</code></a></span></li><li><span><a href="#Уровень-занимаемой-должности-level" data-toc-modified-id="Уровень-занимаемой-должности-level-1.3.2"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>Уровень занимаемой должности <code>level</code></a></span></li><li><span><a href="#Уровень-загруженности-сотрудника-workload" data-toc-modified-id="Уровень-загруженности-сотрудника-workload-1.3.3"><span class="toc-item-num">1.3.3&nbsp;&nbsp;</span>Уровень загруженности сотрудника <code>workload</code></a></span></li><li><span><a href="#Длительность-работы-в-компании-employment_years" data-toc-modified-id="Длительность-работы-в-компании-employment_years-1.3.4"><span class="toc-item-num">1.3.4&nbsp;&nbsp;</span>Длительность работы в компании <code>employment_years</code></a></span></li><li><span><a href="#Повышение-за-последний-год-last_year_promo" data-toc-modified-id="Повышение-за-последний-год-last_year_promo-1.3.5"><span class="toc-item-num">1.3.5&nbsp;&nbsp;</span>Повышение за последний год <code>last_year_promo</code></a></span></li><li><span><a href="#Нарушения-сотрудником-трудового-договора-last_year_violations" data-toc-modified-id="Нарушения-сотрудником-трудового-договора-last_year_violations-1.3.6"><span class="toc-item-num">1.3.6&nbsp;&nbsp;</span>Нарушения сотрудником трудового договора <code>last_year_violations</code></a></span></li><li><span><a href="#Оценка-руководителем-качества-работы-сотрудника-supervisor_evaluation" data-toc-modified-id="Оценка-руководителем-качества-работы-сотрудника-supervisor_evaluation-1.3.7"><span class="toc-item-num">1.3.7&nbsp;&nbsp;</span>Оценка руководителем качества работы сотрудника <code>supervisor_evaluation</code></a></span></li><li><span><a href="#Ежемесячная-зарплата-сотрудника-salary" data-toc-modified-id="Ежемесячная-зарплата-сотрудника-salary-1.3.8"><span class="toc-item-num">1.3.8&nbsp;&nbsp;</span>Ежемесячная зарплата сотрудника <code>salary</code></a></span></li><li><span><a href="#Уровень-удовлетворённости-сотрудника-работой-в-компании,-целевой-признак-job_satisfaction_rate" data-toc-modified-id="Уровень-удовлетворённости-сотрудника-работой-в-компании,-целевой-признак-job_satisfaction_rate-1.3.9"><span class="toc-item-num">1.3.9&nbsp;&nbsp;</span>Уровень удовлетворённости сотрудника работой в компании, целевой признак <code>job_satisfaction_rate</code></a></span></li><li><span><a href="#Анализ-корреляции-признаков-для-тренировочной-выборки" data-toc-modified-id="Анализ-корреляции-признаков-для-тренировочной-выборки-1.3.10"><span class="toc-item-num">1.3.10&nbsp;&nbsp;</span>Анализ корреляции признаков для тренировочной выборки</a></span></li><li><span><a href="#Анализ-корреляции-признаков-для-тестовой-выборки" data-toc-modified-id="Анализ-корреляции-признаков-для-тестовой-выборки-1.3.11"><span class="toc-item-num">1.3.11&nbsp;&nbsp;</span>Анализ корреляции признаков для тестовой выборки</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-1.3.12"><span class="toc-item-num">1.3.12&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Подготовка данных</a></span></li><li><span><a href="#Обучение-моделей" data-toc-modified-id="Обучение-моделей-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Обучение моделей</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Задача:-предсказание-увольнения-сотрудника-из-компании" data-toc-modified-id="Задача:-предсказание-увольнения-сотрудника-из-компании-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Задача: предсказание увольнения сотрудника из компании</a></span><ul class="toc-item"><li><span><a href="#Загрузка-данных" data-toc-modified-id="Загрузка-данных-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Загрузка данных</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#train_quit" data-toc-modified-id="train_quit-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>train_quit</a></span></li><li><span><a href="#test_target_quit" data-toc-modified-id="test_target_quit-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>test_target_quit</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Отдел,-в-котором-работает-сотрудник-dept" data-toc-modified-id="Отдел,-в-котором-работает-сотрудник-dept-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Отдел, в котором работает сотрудник <code>dept</code></a></span></li><li><span><a href="#Уровень-занимаемой-должности-level" data-toc-modified-id="Уровень-занимаемой-должности-level-2.3.2"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span>Уровень занимаемой должности <code>level</code></a></span></li><li><span><a href="#Уровень-загруженности-сотрудника-workload" data-toc-modified-id="Уровень-загруженности-сотрудника-workload-2.3.3"><span class="toc-item-num">2.3.3&nbsp;&nbsp;</span>Уровень загруженности сотрудника <code>workload</code></a></span></li><li><span><a href="#Длительность-работы-в-компании-employment_years" data-toc-modified-id="Длительность-работы-в-компании-employment_years-2.3.4"><span class="toc-item-num">2.3.4&nbsp;&nbsp;</span>Длительность работы в компании <code>employment_years</code></a></span></li><li><span><a href="#Повышение-за-последний-год-last_year_promo" data-toc-modified-id="Повышение-за-последний-год-last_year_promo-2.3.5"><span class="toc-item-num">2.3.5&nbsp;&nbsp;</span>Повышение за последний год <code>last_year_promo</code></a></span></li><li><span><a href="#Нарушения-сотрудником-трудового-договора-last_year_violations" data-toc-modified-id="Нарушения-сотрудником-трудового-договора-last_year_violations-2.3.6"><span class="toc-item-num">2.3.6&nbsp;&nbsp;</span>Нарушения сотрудником трудового договора <code>last_year_violations</code></a></span></li><li><span><a href="#Оценка-руководителем-качества-работы-сотрудника-supervisor_evaluation" data-toc-modified-id="Оценка-руководителем-качества-работы-сотрудника-supervisor_evaluation-2.3.7"><span class="toc-item-num">2.3.7&nbsp;&nbsp;</span>Оценка руководителем качества работы сотрудника <code>supervisor_evaluation</code></a></span></li><li><span><a href="#Ежемесячная-зарплата-сотрудника-salary" data-toc-modified-id="Ежемесячная-зарплата-сотрудника-salary-2.3.8"><span class="toc-item-num">2.3.8&nbsp;&nbsp;</span>Ежемесячная зарплата сотрудника <code>salary</code></a></span></li><li><span><a href="#Целевой-признак-quit" data-toc-modified-id="Целевой-признак-quit-2.3.9"><span class="toc-item-num">2.3.9&nbsp;&nbsp;</span>Целевой признак <code>quit</code></a></span></li><li><span><a href="#Анализ-корреляции-признаков-на-тренировочной-выборке" data-toc-modified-id="Анализ-корреляции-признаков-на-тренировочной-выборке-2.3.10"><span class="toc-item-num">2.3.10&nbsp;&nbsp;</span>Анализ корреляции признаков на тренировочной выборке</a></span></li><li><span><a href="#Анализ-корреляции-признаков-на-тестовой-выборке" data-toc-modified-id="Анализ-корреляции-признаков-на-тестовой-выборке-2.3.11"><span class="toc-item-num">2.3.11&nbsp;&nbsp;</span>Анализ корреляции признаков на тестовой выборке</a></span></li><li><span><a href="#Портрет-«уволившегося-сотрудника»" data-toc-modified-id="Портрет-«уволившегося-сотрудника»-2.3.12"><span class="toc-item-num">2.3.12&nbsp;&nbsp;</span>Портрет «уволившегося сотрудника»</a></span></li><li><span><a href="#Влияние-удовлетворенности-на-увольнение-(3.3)" data-toc-modified-id="Влияние-удовлетворенности-на-увольнение-(3.3)-2.3.13"><span class="toc-item-num">2.3.13&nbsp;&nbsp;</span>Влияние удовлетворенности на увольнение (3.3)</a></span></li></ul></li><li><span><a href="#Добавление-нового-входного-признака" data-toc-modified-id="Добавление-нового-входного-признака-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Добавление нового входного признака</a></span></li><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Подготовка данных</a></span></li><li><span><a href="#Обучение-моделей" data-toc-modified-id="Обучение-моделей-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Обучение моделей</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Общий вывод</a></span></li></ul></div>

# %% [markdown]
# <h1>Проект: HR-аналитика.<span class="tocSkip"></span></h1>

# %% [markdown]
# HR-аналитики компании «Работа с заботой» помогают бизнесу оптимизировать управление персоналом: бизнес предоставляет данные, а аналитики предлагают, как избежать финансовых потерь и оттока сотрудников. В этом HR-аналитикам пригодится машинное обучение, с помощью которого получится быстрее и точнее отвечать на вопросы бизнеса.
# Компания предоставила данные с характеристиками сотрудников компании. Среди них — уровень удовлетворённости сотрудника работой в компании. Эту информацию получили из форм обратной связи: сотрудники заполняют тест-опросник, и по его результатам рассчитывается доля их удовлетворённости от 0 до 1, где 0 — совершенно неудовлетворён, 1 — полностью удовлетворён.
#
# Собирать данные такими опросниками не так легко: компания большая, и всех сотрудников надо сначала оповестить об опросе, а затем проследить, что все его прошли.
# У нас будет несколько задач. Первая — построить модель, которая сможет предсказать уровень удовлетворённости сотрудника на основе данных заказчика.
#
# Почему бизнесу это важно: удовлетворённость работой напрямую влияет на отток сотрудников. А предсказание оттока — одна из важнейших задач HR-аналитиков. Внезапные увольнения несут в себе риски для компании, особенно если уходит важный сотрудник.
# Наша вторая задача — построить модель, которая сможет на основе данных заказчика предсказать то, что сотрудник уволится из компании.

# %% [markdown]
# # Задача: предсказание уровня удовлетворённости сотрудника

# %% [markdown]
# Для этой задачи заказчик предоставил данные с признаками:
# - id — уникальный идентификатор сотрудника;
# - dept — отдел, в котором работает сотрудник;
# - level — уровень занимаемой должности;
# - workload — уровень загруженности сотрудника;
# - employment_years — длительность работы в компании (в годах);
# - last_year_promo — показывает, было ли повышение за последний год;
# - last_year_violations — показывает, нарушал ли сотрудник трудовой договор за последний год;
# - supervisor_evaluation — оценка качества работы сотрудника, которую дал руководитель;
# - salary — ежемесячная зарплата сотрудника;
# - job_satisfaction_rate — уровень удовлетворённости сотрудника работой в компании, целевой признак.

# %% [markdown]
# ## Загрузка данных

# %% [markdown]
# Импортируем необходимые библиотеки.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats as st
import seaborn as sns
import phik

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import (
    OneHotEncoder, OrdinalEncoder, StandardScaler, MinMaxScaler, RobustScaler, PolynomialFeatures
)
from sklearn.linear_model import (
    LinearRegression,
    LogisticRegression
)
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    r2_score,
    precision_score,
    recall_score,
    root_mean_squared_error,
    mean_squared_error,
    mean_absolute_error,
    roc_auc_score,
    make_scorer
)
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from optuna.integration import OptunaSearchCV

from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression, ElasticNet
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.dummy import DummyRegressor, DummyClassifier

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### train_job_satisfaction_rate

# %%
train_job_satisfaction_rate.head(30)
# Out:
#         id        dept   level workload  employment_years last_year_promo  \
# 0   155278       sales  junior   medium                 2              no
# 1   653870          hr  junior     high                 2              no
# 2   184592       sales  junior      low                 1              no
# 3   171431  technology  junior      low                 4              no
# 4   693419          hr  junior   medium                 1              no
# 5   405448          hr  middle      low                 7              no
# 6   857135       sales  sinior   medium                 9              no
# 7   400657  purchasing  middle     high                 9              no
# 8   198846          hr  junior      low                 1              no
# 9   149797  technology  middle     high                 6              no
# 10  964158  purchasing  junior      low                 2              no
# 11  784541       sales  middle      low                 3              no
# ...

# %%
train_job_satisfaction_rate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     4000 non-null   int64
#  1   dept                   3994 non-null   object
#  2   level                  3996 non-null   object
#  3   workload               4000 non-null   object
#  4   employment_years       4000 non-null   int64
#  5   last_year_promo        4000 non-null   object
#  6   last_year_violations   4000 non-null   object
#  7   supervisor_evaluation  4000 non-null   int64
#  8   salary                 4000 non-null   int64
#  9   job_satisfaction_rate  4000 non-null   float64
# dtypes: float64(1), int64(4), object(5)
# memory usage: 312.6+ KB

# %% [markdown]
# Проверим пропуски.

# %%
train_job_satisfaction_rate.isna().sum()
# Out:
# id                       0
# dept                     6
# level                    4
# workload                 0
# employment_years         0
# last_year_promo          0
# last_year_violations     0
# supervisor_evaluation    0
# salary                   0
# job_satisfaction_rate    0
# dtype: int64

# %% [markdown]
# Проверим категориальные признаки

# %%
print(train_job_satisfaction_rate['dept'].unique(),
train_job_satisfaction_rate['level'].unique(),
train_job_satisfaction_rate['workload'].unique(),
train_job_satisfaction_rate['last_year_promo'].unique(),
train_job_satisfaction_rate['last_year_violations'].unique())
# Out:
# ['sales' 'hr' 'technology' 'purchasing' 'marketing' nan] ['junior' 'middle' 'sinior' nan] ['medium' 'high' 'low'] ['no' 'yes'] ['no' 'yes']

# %% [markdown]
# Необходимо 'sinior' заменить на 'senior'.
# nan будет заменен в пайплайне

# %%
train_job_satisfaction_rate['level'] = train_job_satisfaction_rate['level'].str.replace(
    'sinior', 'senior'
)

# %% [markdown]
# Проверим строки-дубликаты

# %%
train_job_satisfaction_rate.duplicated(
    subset=[
        'dept',
        'level',
        'workload',
        'employment_years',
        'last_year_promo',
        'last_year_violations',
        'supervisor_evaluation',
        'salary',
        'job_satisfaction_rate'
    ]
).sum()
# Out:
# np.int64(245)

# %% [markdown]
# Удалим дубликаты перед машинным обучением. С точки зрения EDA дубликаты описывают особенности распределения и должны быть учтены в анализе, в то же время их наличие в машинном обучении может привести к неявной утечке при проведении кросс-валидации.

# %% [markdown]
# ### test_features

# %%
test_features.head(30)
# Out:
#         id        dept   level workload  employment_years last_year_promo  \
# 0   485046   marketing  junior   medium                 2              no
# 1   686555          hr  junior   medium                 1              no
# 2   467458       sales  middle      low                 5              no
# 3   418655       sales  middle      low                 6              no
# 4   789145          hr  middle   medium                 5              no
# 5   429973  purchasing  middle   medium                 6              no
# 6   850699  technology  junior   medium                 3              no
# 7   500791       sales  middle     high                 9              no
# 8   767867   marketing  middle     high                 3              no
# 9   937235       sales  junior   medium                 1              no
# 10  354261  technology  junior      low                 3              no
# 11  473072          hr  middle   medium                 1              no
# ...

# %%
test_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     2000 non-null   int64
#  1   dept                   1998 non-null   object
#  2   level                  1999 non-null   object
#  3   workload               2000 non-null   object
#  4   employment_years       2000 non-null   int64
#  5   last_year_promo        2000 non-null   object
#  6   last_year_violations   2000 non-null   object
#  7   supervisor_evaluation  2000 non-null   int64
#  8   salary                 2000 non-null   int64
# dtypes: int64(4), object(5)
# memory usage: 140.8+ KB

# %% [markdown]
# Проверим категориальные признаки

# %%
print(test_features['dept'].unique(),
test_features['level'].unique(),
test_features['workload'].unique(),
test_features['last_year_promo'].unique(),
test_features['last_year_violations'].unique())
# Out:
# ['marketing' 'hr' 'sales' 'purchasing' 'technology' nan ' '] ['junior' 'middle' 'sinior' nan] ['medium' 'low' 'high' ' '] ['no' 'yes'] ['no' 'yes']

# %% [markdown]
# Необходимо 'sinior' заменить на 'senior'. Пробелы заменим на nan, а сам nan будет заменен в пайплайне

# %%
test_features['level'] = test_features['level'].replace(' ', np.nan)
test_features['dept'] = test_features['dept'].replace(' ', np.nan)
test_features['workload'] = test_features['workload'].replace(' ', np.nan)
test_features['level'] = test_features['level'].str.replace(
    'sinior', 'senior'
)

# %% [markdown]
# Проверим строки-дубликаты

# %%
test_features.duplicated(
    subset=[
        'dept',
        'level',
        'workload',
        'employment_years',
        'last_year_promo',
        'last_year_violations',
        'supervisor_evaluation',
        'salary',
    ]
).sum()
# Out:
# np.int64(557)

# %% [markdown]
# Удалять дубликаты не будем, так как наличие дубликатов в `test` нам никак не мешает, но это правильное решение с точки зрения неприкосновенности `test`, ведь реальный поток данных (который имитирует `test` выборка) мы исправить не сможем. А вот наличие дубликатов в `train` не только не принесёт пользы модели, но может и навредить.

# %% [markdown]
# ### test_target_job_satisfaction_rate

# %%
test_target_job_satisfaction_rate.head(30)
# Out:
#         id  job_satisfaction_rate
# 0   130604                   0.74
# 1   825977                   0.75
# 2   418490                   0.60
# 3   555320                   0.72
# 4   826430                   0.08
# 5   817219                   0.76
# 6   269033                   0.64
# 7   962356                   0.38
# 8   649052                   0.14
# 9   532834                   0.59
# 10  436938                   0.91
# 11  759748                   0.78
# 12  462750                   0.70
# 13  120724                   0.79
# 14  161234                   0.74
# 15  217807                   0.34
# 16  311719                   0.81
# 17  377223                   0.23
# 18  700796                   0.23
# 19  304609                   0.40
# 20  508688                   0.58
# 21  467527                   0.77
# 22  906310                   0.68
# 23  193643                   0.64
# 24  561171                   0.24
# 25  952435                   0.42
# ...

# %%
test_target_job_satisfaction_rate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     2000 non-null   int64
#  1   job_satisfaction_rate  2000 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 31.4 KB

# %% [markdown]
# **Выводы по предобработке данных:**
#
# В ходе предобработки данных были исключены дубликаты, а также изменены некоторые наименования в категориальных данных.

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# Рассмотрим признаки в каждом из датафреймов. Для удобства будем рассматривать признак сразу из обоих датафреймов, так как они почти полностью совпадают.

# %% [markdown]
# ### Отдел, в котором работает сотрудник `dept`

# %%
train_job_satisfaction_rate['dept'].value_counts().plot(
    kind='bar',
    grid=True,
    xlabel='Отдел',
    ylabel='Частота',
    title='Количество сотрудников в отделах'
);

# %%
test_features['dept'].value_counts().plot(
    kind='bar',
    grid=True,
    xlabel='Отдел',
    ylabel='Частота',
    title='Количество сотрудников в отделах'
);

# %% [markdown]
# ### Уровень занимаемой должности `level`

# %%
train_job_satisfaction_rate['level'].value_counts().plot(
    kind='bar',
    grid=True,
    xlabel='Уровень',
    ylabel='Частота',
    title='Количество сотрудников на разных уровнях'
);

# %%
test_features['level'].value_counts().plot(
    kind='bar',
    grid=True,
    xlabel='Уровень',
    ylabel='Частота',
    title='Количество сотрудников на разных уровнях'
);

# %% [markdown]
# Больше всего в компании сотрудников на junior и middle позициях, меньше всего сотрудников на позициях senior.

# %% [markdown]
# ### Уровень загруженности сотрудника `workload`

# %%
train_job_satisfaction_rate['workload'].value_counts().plot(
    kind='bar',
    grid=True,
    xlabel='Уровень',
    ylabel='Частота',
    title='Уровень загруженности сотрудника'
);

# %%
test_features['workload'].value_counts().plot(
    kind='bar',
    grid=True,
    xlabel='Уровень',
    ylabel='Частота',
    title='Уровень загруженности сотрудника'
);

# %% [markdown]
# Половина сотрудников загружена на среднем уровне, 30% - на низком и 20% - на высоком

# %% [markdown]
# ### Длительность работы в компании `employment_years`

# %%
train_job_satisfaction_rate['employment_years'].value_counts().plot(
    kind='bar',
    grid=True,
    xlabel='Длительность',
    ylabel='Частота',
    title='Длительность работы в компании'
);

# %%
test_features['employment_years'].value_counts().plot(
    kind='bar',
    grid=True,
    xlabel='Длительность',
    ylabel='Частота',
    title='Длительность работы в компании'
);

# %% [markdown]
# Больше всего сотрудников с 1-2 годами работы в компании. Дальше количество убывает.

# %% [markdown]
# ### Повышение за последний год `last_year_promo`

# %%
train_job_satisfaction_rate['last_year_promo'].value_counts().plot(
    kind='pie',
    autopct='%1.1f%%',
    figsize=(7, 7),
    title='Повышение за последний год'
);

# %%
test_features['last_year_promo'].value_counts().plot(
    kind='pie',
    autopct='%1.1f%%',
    figsize=(7, 7),
    title='Повышение за последний год'
);

# %% [markdown]
# Только у 3-4% сотрудников было повышение за последний год.

# %% [markdown]
# ###  Нарушения сотрудником трудового договора `last_year_violations`

# %%
train_job_satisfaction_rate['last_year_violations'].value_counts().plot(
    kind='pie',
    autopct='%1.1f%%',
    figsize=(7, 7),
    title='Нарушения трудового договора'
);

# %%
test_features['last_year_violations'].value_counts().plot(
    kind='pie',
    autopct='%1.1f%%',
    figsize=(7, 7),
    title='Нарушения трудового договора'
);

# %% [markdown]
# 14-16% сотрудников нарушали трудовой договор за последний год.

# %% [markdown]
# ### Оценка руководителем качества работы сотрудника `supervisor_evaluation`

# %%
train_job_satisfaction_rate['supervisor_evaluation'].value_counts().plot(
    kind='pie',
    autopct='%1.1f%%',
    figsize=(7, 7),
    title='Оценка руководителем качества работы сотрудника'
);

# %%
test_features['supervisor_evaluation'].value_counts().plot(
    kind='pie',
    autopct='%1.1f%%',
    figsize=(7, 7),
    title='Оценка руководителем качества работы сотрудника'
);

# %% [markdown]
# 70% сотрудников оценены на 3-4, 15% - на 5, 15% - на 1-2

# %% [markdown]
# ### Ежемесячная зарплата сотрудника `salary`

# %%
train_job_satisfaction_rate['salary'].plot(
    kind='hist',
    bins=25,
    grid=True,
    title='Ежемесячная зарплата сотрудника',
    xlabel='Зарплата',
    ylabel='Частота'
);

# %%
test_features['salary'].plot(
    kind='hist',
    bins=25,
    grid=True,
    title='Ежемесячная зарплата сотрудника',
    xlabel='Зарплата',
    ylabel='Частота'
);

# %%
train_job_satisfaction_rate['salary'].describe()
# Out:
# count     4000.000000
# mean     33926.700000
# std      14900.703838
# min      12000.000000
# 25%      22800.000000
# 50%      30000.000000
# 75%      43200.000000
# max      98400.000000
# Name: salary, dtype: float64

# %% [markdown]
# - Средняя зарплата 34 тыс.
# - Медианная 31 тыс.
# - Минимальная зарплата 12 тыс.
# - Максимальная 98 тыс.

# %% [markdown]
# ### Уровень удовлетворённости сотрудника работой в компании, целевой признак `job_satisfaction_rate`

# %%
train_job_satisfaction_rate['job_satisfaction_rate'].plot(
    kind='hist',
    bins=25,
    grid=True,
    title='Удовлетворенность сотрудника работой в компании',
    xlabel='Уровень',
    ylabel='Частота'
);

# %%
train_job_satisfaction_rate['job_satisfaction_rate'].describe()
# Out:
# count    4000.000000
# mean        0.533995
# std         0.225327
# min         0.030000
# 25%         0.360000
# 50%         0.560000
# 75%         0.710000
# max         1.000000
# Name: job_satisfaction_rate, dtype: float64

# %% [markdown]
# Среднее значение 0.53, медианное 0.55

# %% [markdown]
# ### Анализ корреляции признаков для тренировочной выборки

# %%
corr_matrix = train_job_satisfaction_rate.drop(columns=['id']).phik_matrix(
    interval_cols=[
        'salary'
    ]
)

# %%
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))
plt.figure(figsize=(8, 6))
sns.heatmap(
    corr_matrix,
    mask=mask,
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    vmin=0,
    vmax=1,
    annot_kws={"fontsize": 8}
)
plt.title('Коэффициенты корреляции между всеми признаками в тренировочной выборке')
plt.show()

# %% [markdown]
# Все коэффициенты корреляции меньше 0.9, следовательно, **мультиколлинеарность отсутствует**
#
# **Средняя связь присутствует между признаками:**
# - Целевой job_satisfaction_rate и last_year_violations
# - level и employment_years
#
#
# **Сильная связь между признаками:**
# - Целевой job_satisfaction_rate и supervisor_evaluation
# - salary и workload
# - salary и level
#
# Остальные связи слабые, незначительные

# %% [markdown]
# ### Анализ корреляции признаков для тестовой выборки

# %%
test = pd.merge(test_features, test_target_job_satisfaction_rate, on='id', how='left')

# %%
corr_matrix = test.drop(columns=['id']).phik_matrix(
    interval_cols=[
        'salary'
    ]
)

# %%
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))
plt.figure(figsize=(8, 6))
sns.heatmap(
    corr_matrix,
    mask=mask,
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    vmin=0,
    vmax=1,
    annot_kws={"fontsize": 8}
)
plt.title('Коэффициенты корреляции между всеми признаками в тестовой выборке')
plt.show()

# %% [markdown]
# Все коэффициенты корреляции меньше 0.9, следовательно, **мультиколлинеарность отсутствует**
#
# **Средняя связь присутствует между признаками:**
# - Целевой job_satisfaction_rate и last_year_violations
# - level и employment_years
# - Целевой job_satisfaction_rate и last_year_promo (данной связи не было у тренировочной выборки)
#
# **Сильная связь между признаками:**
# - Целевой job_satisfaction_rate и supervisor_evaluation
# - salary и workload
# - salary и level
#
#
# Остальные связи слабые, незначительные
#
# В данных нет существенных различий в части распределений признаков и оценка модели, полученная на test выборке, будет корректной.

# %% [markdown]
# ### Выводы

# %% [markdown]
# В ходе исследовательского анализа данных не выявлено выбросов и аномалий. Все признаки, кроме зарплаты и целевого, являются категориальными.
#
# - Будем использовать OrdinalEncoder для level, workload, employment_years, supervisor_evaluation
#
# - Будем использовать OneHotEncoder для dept, last_year_promo, last_year_violations
#
# - StandardScaler и MinMaxScaler переберем при помощи кросс-валидации для количественных признаков.
#
# В ходе корреляционного анализа признаков мультиколлинеарность не была выявлена. Есть несколько сильных и средних связей между признаками. У целевого признака сильная связь с supervisor_evaluation и средняя связь с last_year_violations_yes

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# Удаление дубликатов, обнаруженных при предобработке данных

# %%
train_job_satisfaction_rate = train_job_satisfaction_rate.drop_duplicates(
    subset=[
        'dept',
        'level',
        'workload',
        'employment_years',
        'last_year_promo',
        'last_year_violations',
        'supervisor_evaluation',
        'salary',
        'job_satisfaction_rate'
    ]
).reset_index(drop=True)

# %%
RANDOM_STATE = 42

X_train = train_job_satisfaction_rate.drop(
    ['id', 'job_satisfaction_rate'], axis=1
)
y_train = train_job_satisfaction_rate['job_satisfaction_rate']
X_test = test.drop(
    ['id', 'job_satisfaction_rate'], axis=1
)
y_test = test['job_satisfaction_rate']

# %%
# создаём списки с названиями признаков
ohe_columns = [
    'dept',
    'last_year_promo',
    'last_year_violations'
]
ord_columns = [
    'level', 'workload'
]
num_columns = [
    'employment_years', 
    'supervisor_evaluation',
    'salary'
    
]

# %% [markdown]
# Создадим пайплайн для подготовки признаков из списка ohe_columns: заполнение пропусков и OHE-кодирование

# %%
# SimpleImputer + OHE
ohe_pip = Pipeline(
    [
        (
            'simpleImputer_ohe',
            SimpleImputer(missing_values=np.nan, strategy='most_frequent')
        ),
        (
            'ohe',
            OneHotEncoder(drop='first', handle_unknown='ignore',
                          sparse_output=False)
        )
    ]
)

# %%
# SimpleImputer + OE
ord_pip = Pipeline(
    [
        (
            'simpleImputer_before_ord',
            SimpleImputer(missing_values=np.nan, strategy='most_frequent')
        ),
        (
            'ord',
            OrdinalEncoder(
                categories=[
                    [
                        'junior',
                        'middle',
                        'senior'
                    ],
                    [
                        'low',
                        'medium',
                        'high'
                    ]
                ],
                handle_unknown='use_encoded_value',
                unknown_value=np.nan

            )
        ),
        (
            'simpleImputer_after_ord',
            SimpleImputer(missing_values=np.nan, strategy='most_frequent')
        )
    ]
)

# %% [markdown]
# Собираем пайплайн для подготовки данных

# %%
data_preprocessor = ColumnTransformer(
    [
        ('ohe', ohe_pip, ohe_columns),
        ('ord', ord_pip, ord_columns),
        ('num', MinMaxScaler(), num_columns)
    ],
    remainder='passthrough'
)

# %% [markdown]
# ## Обучение моделей

# %%
def smape(y_true, y_pred):
    y_true = np.asarray(y_true)
    y_pred = np.asarray(y_pred)

    # Проверка на нулевые значения в знаменателе
    denominator = np.abs(y_true) + np.abs(y_pred)
    smape_values = np.where(denominator == 0, 0, 2 *
                            np.abs(y_true - y_pred) / denominator)
    
    return float(np.mean(smape_values) * 100)

# %%
smape_scorer = make_scorer(smape, greater_is_better=False)

# %%
pipe_final = Pipeline([
    ('preprocessor', data_preprocessor),
    ('models', DecisionTreeRegressor(random_state=RANDOM_STATE))
])

# %%
param_grid = [
    # Словарь для модели DecisionTreeRegressor()
    {
        'models': [DecisionTreeRegressor(random_state=RANDOM_STATE)],
        'models__max_depth': range(5, 15),
        'models__max_features': range(5, 10),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough'],
        'models__min_samples_split': range(2, 10),
        'models__min_samples_leaf': range(1, 4),
        
    },

    # Словарь для модели LinearRegression()
    {
        'models': [LinearRegression()],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough'],
    },
]

# %%
grid_search = GridSearchCV(
    pipe_final,
    param_grid,
    cv=11,
    scoring=smape_scorer,
    n_jobs=-1
)
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=11,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('ohe',
#                                                                          Pipeline(steps=[('simpleImputer_ohe',
#                                                                                           SimpleImputer(strategy='most_frequent')),
#                                                                                          ('ohe',
#                                                                                           OneHotEncoder(drop='first',
#                                                                                                         handle_unknown='ignore',
#                                                                                                         sparse_output=False))]),
# ...

# %%
print("Лучшая модель:", grid_search.best_params_)
# Out:
# Лучшая модель: {'models': DecisionTreeRegressor(random_state=42), 'models__max_depth': 13, 'models__max_features': 8, 'models__min_samples_leaf': 2, 'models__min_samples_split': 8, 'preprocessor__num': StandardScaler()}

# %%
print(
    f'Метрика SMAPE на кросс-валидации: {-grid_search.best_score_}')
y_test_pred = grid_search.predict(X_test)
print(
    f'Метрика SMAPE на тестовой выборке: {smape(y_test, y_test_pred)}')
# Out:
# Метрика SMAPE на кросс-валидации: 14.869167712872375
# Метрика SMAPE на тестовой выборке: 13.64918282758467

# %% [markdown]
# Лучшая модель - DecisionTreeRegressor с параметрами models__max_depth = 13, models__max_features = 8, models__min_samples_leaf = 2, models__min_samples_split = 8,
# Метрика SMAPE на тестовой выборке: 13.64918282758467, что соответствует критерию успеха

# %% [markdown]
# Проверим лучшую модель на адекватность.

# %%
dummy_regr = DummyRegressor(strategy="mean")
dummy_regr.fit(X_train, y_train)
dummy_regr_pred = dummy_regr.predict(X_test)
smape(y_test, dummy_regr_pred)
# Out:
# 38.26225790202237

# %% [markdown]
# Результат тестирования нашей модели на тествой выборке был лучше, чем результат константной модели

# %% [markdown]
# ## Выводы

# %% [markdown]
# С данной задачей лучше всего справилась модель дерева решений, так как она ищет больше каких-либо закономерностей в данных в отличие от линейной регрессии

# %% [markdown]
# # Задача: предсказание увольнения сотрудника из компании

# %% [markdown]
# ## Загрузка данных

# %% [markdown]
# В данном разделе загружены данные,

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### train_quit

# %%
train_quit.head(30)
# Out:
#         id        dept   level workload  employment_years last_year_promo  \
# 0   723290       sales  middle     high                 2              no
# 1   814010       sales  junior   medium                 2              no
# 2   155091  purchasing  middle   medium                 5              no
# 3   257132       sales  junior   medium                 2              no
# 4   910140   marketing  junior   medium                 2              no
# 5   699916       sales  junior      low                 1              no
# 6   417070  technology  middle   medium                 8              no
# 7   165489       sales  middle      low                 4              no
# 8   996399   marketing  middle      low                 7              no
# 9   613206  technology  middle   medium                 2              no
# 10  832644       sales  middle     high                 3              no
# 11  260997       sales  middle   medium                 5              no
# ...

# %%
train_quit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     4000 non-null   int64
#  1   dept                   4000 non-null   object
#  2   level                  4000 non-null   object
#  3   workload               4000 non-null   object
#  4   employment_years       4000 non-null   int64
#  5   last_year_promo        4000 non-null   object
#  6   last_year_violations   4000 non-null   object
#  7   supervisor_evaluation  4000 non-null   int64
#  8   salary                 4000 non-null   int64
#  9   quit                   4000 non-null   object
# dtypes: int64(4), object(6)
# memory usage: 312.6+ KB

# %% [markdown]
# Проверим категориальные признаки

# %%
print(train_quit['dept'].unique(),
    train_quit['level'].unique(),
    train_quit['workload'].unique(),
    train_quit['last_year_promo'].unique(),
    train_quit['last_year_violations'].unique(),
    train_quit['quit'].unique()
     )
# Out:
# ['sales' 'purchasing' 'marketing' 'technology' 'hr'] ['middle' 'junior' 'sinior'] ['high' 'medium' 'low'] ['no' 'yes'] ['no' 'yes'] ['no' 'yes']

# %% [markdown]
# Необходимо 'sinior' заменить на 'senior'.

# %%
train_quit['level'] = train_quit['level'].str.replace(
    'sinior', 'senior'
)

# %%
train_quit.duplicated(
    subset=[
        'dept',
        'level',
        'workload',
        'employment_years',
        'last_year_promo',
        'last_year_violations',
        'supervisor_evaluation',
        'salary',
        'quit'
    ]
).sum()
# Out:
# np.int64(1413)

# %% [markdown]
# Удалим дубликаты перед обучением моделей.

# %% [markdown]
# ### test_target_quit

# %%
test_target_quit.head()
# Out:
#        id quit
# 0  999029  yes
# 1  372846   no
# 2  726767   no
# 3  490105   no
# 4  416898  yes

# %%
test_target_quit['quit'].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Отдел, в котором работает сотрудник `dept`

# %%
train_quit['dept'].value_counts().plot(
    kind='bar',
    grid=True,
    xlabel='Отдел',
    ylabel='Частота',
    title='Количество сотрудников в отделах'
);

# %% [markdown]
# ### Уровень занимаемой должности `level`

# %%
train_quit['level'].value_counts().plot(
    kind='bar',
    grid=True,
    xlabel='Уровень',
    ylabel='Частота',
    title='Количество сотрудников на разных уровнях'
);

# %% [markdown]
# ### Уровень загруженности сотрудника `workload`

# %%
train_quit['workload'].value_counts().plot(
    kind='bar',
    grid=True,
    xlabel='Уровень',
    ylabel='Частота',
    title='Уровень загруженности сотрудника'
);

# %% [markdown]
# ### Длительность работы в компании `employment_years`

# %%
train_quit['employment_years'].value_counts().plot(
    kind='bar',
    grid=True,
    xlabel='Длительность',
    ylabel='Частота',
    title='Длительность работы в компании'
);

# %% [markdown]
# ### Повышение за последний год `last_year_promo`

# %%
train_quit['last_year_promo'].value_counts().plot(
    kind='pie',
    autopct='%1.1f%%',
    figsize=(7, 7),
    title='Повышение за последний год'
);

# %% [markdown]
# ###  Нарушения сотрудником трудового договора `last_year_violations`

# %%
train_quit['last_year_violations'].value_counts().plot(
    kind='pie',
    autopct='%1.1f%%',
    figsize=(7, 7),
    title='Нарушения трудового договора'
);

# %% [markdown]
# ### Оценка руководителем качества работы сотрудника `supervisor_evaluation`

# %%
train_quit['supervisor_evaluation'].value_counts().plot(
    kind='pie',
    autopct='%1.1f%%',
    figsize=(7, 7),
    title='Оценка руководителем качества работы сотрудника'
);

# %% [markdown]
# ### Ежемесячная зарплата сотрудника `salary`

# %%
train_quit['salary'].plot(
    kind='hist',
    bins=25,
    grid=True,
    title='Ежемесячная зарплата сотрудника',
    xlabel='Зарплата',
    ylabel='Частота'
);

# %% [markdown]
# ### Целевой признак `quit`

# %%
train_quit['quit'].value_counts().plot(
    kind='bar',
    grid=True,
    xlabel='Уровень',
    ylabel='Частота',
    title='Уровень загруженности сотрудника'
);

# %% [markdown]
# У целевого признака наблюдается дисбаланс классов. ROC-AUC лучше всего подойдет в этом случае.

# %% [markdown]
# ### Анализ корреляции признаков на тренировочной выборке

# %%
corr_matrix = train_quit.drop(columns=['id']).phik_matrix(
    interval_cols=[
        'salary'
    ]
)

mask = np.triu(np.ones_like(corr_matrix, dtype=bool))
plt.figure(figsize=(8, 6))
sns.heatmap(
    corr_matrix,
    mask=mask,
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    vmin=0,
    vmax=1,
    annot_kws={"fontsize": 8}
)
plt.title('Коэффициенты корреляции между всеми признаками')
plt.show()

# %% [markdown]
# Все коэффициенты корреляции меньше 0.9, следовательно, **мультиколлинеарность отсутствует**
#
# **Средняя связь присутствует между признаками:**
# - Целевой quit и employment_years
# - Целевой quit и salary
# - level и employment_years
#
# **Сильная связь между признаками:**
# - salary и workload
# - salary и level
#
# Остальные связи слабые, незначительные

# %% [markdown]
# ### Анализ корреляции признаков на тестовой выборке

# %%
test = pd.merge(test, test_target_quit, on='id', how='left')

# %%
corr_matrix = test.drop(columns=['id']).phik_matrix(
    interval_cols=[
        'salary'
    ]
)

# %%
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))
plt.figure(figsize=(8, 6))
sns.heatmap(
    corr_matrix,
    mask=mask,
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    vmin=0,
    vmax=1,
    annot_kws={"fontsize": 8}
)
plt.title('Коэффициенты корреляции между всеми признаками в тестовой выборке')
plt.show()

# %% [markdown]
# Все коэффициенты корреляции меньше 0.9, следовательно, **мультиколлинеарность отсутствует**
#
# **Средняя связь присутствует между признаками:**
# - Целевой quit и employment_years
# - Целевой quit и salary
# - level и employment_years
#
# **Сильная связь между признаками:**
# - salary и workload
# - salary и level
#
# Также добавились связи с job_satisfaction_rate:
# - Средняя с last_year_promo
# - Средняя с last_year_violations
# - Средняя с quit
# - Сильная с supervisor_evaluation
#
# Остальные связи слабые, незначительные
#
# В данных нет существенных различий в части распределений признаков и оценка модели, полученная на test выборке, будет корректной.

# %% [markdown]
# ### Портрет «уволившегося сотрудника»

# %%
train_quit.loc[train_quit['quit'] == 'yes']['dept'].value_counts(normalize=True).plot(
    kind='pie',
    autopct='%1.1f%%',
    figsize=(7, 7),
    title='Количество сотрудников в отделах'
);

# %%
train_quit.loc[train_quit['quit'] == 'yes']['level'].value_counts(normalize=True).plot(
    kind='bar',
    grid=True,
    xlabel='Должность',
    ylabel='Частота',
    title='Количество сотрудников по должностям'
);

# %%
train_quit.loc[train_quit['quit'] == 'yes']['workload'].value_counts(normalize=True).plot(
    kind='bar',
    grid=True,
    xlabel='Нагрузка',
    ylabel='Частота',
    title='Количество сотрудников по нагрузке'
);

# %%
train_quit.loc[train_quit['quit'] == 'yes']['supervisor_evaluation'].value_counts(normalize=True).plot(
    kind='bar',
    grid=True,
    xlabel='Оценка',
    ylabel='Частота',
    title='Оценка работодателя'
);

# %%
train_quit.loc[train_quit['quit'] == 'yes']['employment_years'].value_counts(normalize=True).plot(
    kind='bar',
    grid=True,
    xlabel='Годы работы',
    ylabel='Частота',
    title='Сколько лет работали уволившиеся'
);

# %%
train_quit.loc[train_quit['quit'] == 'yes']['last_year_promo'].value_counts(normalize=True).plot(
    kind='bar',
    grid=True,
    xlabel='Количество',
    ylabel='Частота',
    title='Повышения за последний год'
);

# %%
train_quit.loc[train_quit['quit'] == 'yes']['last_year_violations'].value_counts(normalize=True).plot(
    kind='bar',
    grid=True,
    xlabel='Количество',
    ylabel='Частота',
    title='Нарушения тредового договора за последний год'
);

# %%
train_quit.loc[train_quit['quit'] == 'yes']['salary'].mean()
# Out:
# np.float64(23885.106382978724)

# %%
train_quit.loc[train_quit['quit'] == 'no']['salary'].mean()
# Out:
# np.float64(37702.22841225627)

# %%
train_quit
# Out:
#           id        dept   level workload  employment_years last_year_promo  \
# 0     723290       sales  middle     high                 2              no
# 1     814010       sales  junior   medium                 2              no
# 2     155091  purchasing  middle   medium                 5              no
# 3     257132       sales  junior   medium                 2              no
# 4     910140   marketing  junior   medium                 2              no
# ...      ...         ...     ...      ...               ...             ...
# 3995  588809       sales  junior   medium                 4              no
# 3996  672059       sales  middle     high                 9              no
# 3997  536432  purchasing  junior      low                 2              no
# 3998  692133  purchasing  middle   medium                 2              no
# 3999  853842       sales  junior   medium                 2              no
#
# ...

# %% [markdown]
# Уволившийся сотрудник с высокой долей вероятности:
# - из отдела продаж или технологий
# - занимает junior позицию
# - был слабо или средне нагружен
# - средняя зарплата уволившихся сотрудников 23 тыс., а оставшихся - 37 тыс.
# - чаще всего увольняются работники, которые меньше всего работали в компании по времени
# - не нарушал трудовой договор за последний год
# - не повышался в должности

# %% [markdown]
# ### Влияние удовлетворенности на увольнение (3.3)

# %% [markdown]
# Аналитики утверждают, что уровень удовлетворённости сотрудника работой в компании влияет на то, уволится ли сотрудник. Визуализируем и сравним распределения признака job_satisfaction_rate для ушедших и оставшихся сотрудников. Будем использовать данные с обоими целевыми признаками тестовой выборки. Добавим целевой признак этой задачи в тестовую выборку прошлой.
#
# **Нулевая гипотеза** - Факт ухода не зависит от удовлетворенности сотрудника компанией
#
# **Альтернативная гипотеза** - Факт ухода зависит от удовлетворенности сотрудника компанией

# %% [markdown]
# Построим распределение job_satisfaction_rate для оставшихся сотрудников

# %%
test.loc[test['quit'] == 'no']['job_satisfaction_rate'].plot(
    kind='hist',
    bins=25,
    grid=True,
    title='Распределение job_satisfaction_rate для оставшихся сотрудников',
    xlabel='job_satisfaction_rate',
    ylabel='Частота'
);

# %% [markdown]
# Построим распределение job_satisfaction_rate для ушедших сотрудников

# %%
test.loc[test['quit'] == 'yes']['job_satisfaction_rate'].plot(
    kind='hist',
    bins=25,
    grid=True,
    title='Распределение job_satisfaction_rate для ушедших сотрудников',
    xlabel='job_satisfaction_rate',
    ylabel='Частота'
);

# %% [markdown]
# Сравним основные характеристики данных распределений

# %%
test.loc[test['quit'] == 'no']['job_satisfaction_rate'].describe()
# Out:
# count    1436.000000
# mean        0.612040
# std         0.199367
# min         0.030000
# 25%         0.500000
# 50%         0.660000
# 75%         0.760000
# max         1.000000
# Name: job_satisfaction_rate, dtype: float64

# %%
test.loc[test['quit'] == 'yes']['job_satisfaction_rate'].describe()
# Out:
# count    564.000000
# mean       0.387713
# std        0.185784
# min        0.040000
# 25%        0.240000
# 50%        0.370000
# 75%        0.492500
# max        0.970000
# Name: job_satisfaction_rate, dtype: float64

# %% [markdown]
# **Нулевая гипотеза** - Факт ухода не зависит от удовлетворенности сотрудника компанией, то есть нет разницы в среднем уровне удовлетворённости работой между теми, кто уволился, и теми, кто остался.
#
# **Альтернативная гипотеза** - Факт ухода зависит от удовлетворенности сотрудника компанией, то есть есть разница в среднем уровне удовлетворённости работой между двумя группами

# %%
satisfaction_quit_yes = test.loc[test['quit'] == 'yes', 'job_satisfaction_rate']
satisfaction_quit_no = test.loc[test['quit'] == 'no', 'job_satisfaction_rate']

t_stat, p_value = st.ttest_ind(satisfaction_quit_yes, satisfaction_quit_no)

print(f"t-статистика: {t_stat}")
print(f"p-value: {p_value}")
# Out:
# t-статистика: -23.074784903634534
# p-value: 1.2311220665171928e-104

# %% [markdown]
# p-value меньше 0.05, поэтому нулевая гипотеза опровергнута, факт ухода зависит от удовлетворенности сотрудника компанией

# %% [markdown]
# Средняя удовлетворенность работой в компании:
# - Уволившиеся - 0.38
# - Оставшиеся - 0.61
#
# Разница значительная, уволившиеся люди чаще всего не удовлетворены работой в компании, а оставшиеся - наоборот. По графикам также видна данная закономерность.

# %% [markdown]
# ## Добавление нового входного признака

# %% [markdown]
# Воспользуемся результатом кросс-валидации `grid_search` из первой задачи.

# %%
train_quit['job_satisfaction_rate'] = grid_search.predict(
    train_quit.drop(columns=['quit']))

test_features['job_satisfaction_rate'] = grid_search.predict(test_features)

# %% [markdown]
# Добавлен новый признак, спрогнозируемый моделью из первой задачи

# %% [markdown]
# ## Подготовка данных

# %%
train_quit = train_quit.drop_duplicates(
    subset=[
        'dept',
        'level',
        'workload',
        'employment_years',
        'last_year_promo',
        'last_year_violations',
        'supervisor_evaluation',
        'salary',
        'quit'
    ]
).reset_index(drop=True)

# %%
X_train = train_quit.drop(
    ['id', 'quit'], axis=1
)
y_train = train_quit['quit']
test = pd.merge(test_features, test_target_quit, on='id', how='left')
X_test = test.drop(
    ['id', 'quit'], axis=1
)
y_test = test['quit']

# %%
ohe_columns = [
    'dept',
    'last_year_promo',
    'last_year_violations'
]
ord_columns = [
    'level', 'workload'
]
num_columns = [
    'employment_years', 
    'supervisor_evaluation',
    'salary',
    'job_satisfaction_rate'
]

# %% [markdown]
# Создадим пайплайн для подготовки признаков из списка ohe_columns: заполнение пропусков и OHE-кодирование

# %%
# SimpleImputer + OHE
ohe_pip = Pipeline(
    [
        (
            'simpleImputer_ohe',
            SimpleImputer(missing_values=np.nan, strategy='most_frequent')
        ),
        (
            'ohe',
            OneHotEncoder(drop='first', handle_unknown='ignore',
                          sparse_output=False)
        )
    ]
)

# %%
# SimpleImputer + OE
ord_pip = Pipeline(
    [
        (
            'simpleImputer_before_ord',
            SimpleImputer(missing_values=np.nan, strategy='most_frequent')
        ),
        (
            'ord',
            OrdinalEncoder(
                categories=[
                    [
                        'junior',
                        'middle',
                        'senior'
                    ],
                    [
                        'low',
                        'medium',
                        'high'
                    ]
                ],
                handle_unknown='use_encoded_value',
                unknown_value=np.nan

            )
        ),
        (
            'simpleImputer_after_ord',
            SimpleImputer(missing_values=np.nan, strategy='most_frequent')
        )
    ]
)

# %% [markdown]
# Собираем пайплайн для подготовки данных

# %%
data_preprocessor = ColumnTransformer(
    [
        ('ohe', ohe_pip, ohe_columns),
        ('ord', ord_pip, ord_columns),
        ('num', MinMaxScaler(), num_columns)
    ],
    remainder='passthrough'
)

# %% [markdown]
# ## Обучение моделей

# %%
from sklearn.preprocessing import PolynomialFeatures

pipe_final_2 = Pipeline([
    ('poly', PolynomialFeatures(degree=3)),
    ('preprocessor', data_preprocessor),
    ('models', DecisionTreeClassifier(random_state=RANDOM_STATE))
])

# %%
param_grid = [
    # словарь для модели DecisionTreeClassifier()
    {
        'models': [DecisionTreeClassifier(random_state=RANDOM_STATE)],
        'models__max_depth': range(2, 5),
        'models__max_features': range(2, 5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']
    },

    # словарь для модели KNeighborsClassifier()
    {
        'models': [KNeighborsClassifier()],
        'models__n_neighbors': range(2, 7),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']
    },

    # словарь для модели LogisticRegression()
    {
        'models': [LogisticRegression(
            random_state=RANDOM_STATE,
            solver='liblinear',
            penalty='l1'
        )],
        'models__C': range(1, 5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']
    },

    # словарь для модели SVC() с ядром rbf
    {
        'models': [SVC(probability=True, random_state=RANDOM_STATE)],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']
    },

    # словарь для модели SVC() с ядром linear
    {
        'models': [SVC(kernel='linear', probability=True, random_state=RANDOM_STATE)],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']
    },

    # словарь для модели SVC() с ядром sigmoid
    {
        'models': [SVC(kernel='sigmoid', probability=True, random_state=RANDOM_STATE)],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']
    },

    # словарь для модели SVC() с ядром poly
    {
        'models': [SVC(kernel='poly', probability=True, random_state=RANDOM_STATE)],
        'models__degree': range(1, 6),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']
    },
]

# %%
randomized_search = RandomizedSearchCV(
    pipe_final,
    param_grid,
    cv=5,
    scoring='roc_auc',
    n_jobs=-1,
    random_state=RANDOM_STATE
)
randomized_search.fit(X_train, y_train)
# Out:
# /opt/anaconda3/envs/practicum/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py:1623: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('preprocessor',
#                                               ColumnTransformer(remainder='passthrough',
#                                                                 transformers=[('ohe',
#                                                                                Pipeline(steps=[('simpleImputer_ohe',
# ...

# %%
print("Лучшая модель:", randomized_search.best_params_)
print(
    f'Метрика ROC-AUC на кросс-валидации: {randomized_search.best_score_}')
y_test_pred = randomized_search.predict_proba(X_test)[:, 1]
print(
    f'Метрика ROC-AUC на тестовой выборке: {roc_auc_score(y_test, y_test_pred)}')
# Out:
# Лучшая модель: {'preprocessor__num': StandardScaler(), 'models__degree': 2, 'models': SVC(kernel='poly', probability=True, random_state=42)}
# Метрика ROC-AUC на кросс-валидации: 0.9064348333724078
# Метрика ROC-AUC на тестовой выборке: 0.9103683893399712

# %% [markdown]
# Метрика ROC-AUC на тестовой выборке равна требуемому значению 0.91

# %% [markdown]
# Было обучено 7 типов моделей с перебором гиперпараметров, SVC с полиноминальным ядром в степени 2 оказалась лучше всех, Метрика ROC-AUC на тестовой выборке: 0.9103683893399712.

# %%
dummy_regr = DummyClassifier()
dummy_regr.fit(X_train, y_train)
dummy_regr_pred = dummy_regr.predict_proba(X_test)[:, 1]
roc_auc_score(y_test, dummy_regr_pred)
# Out:
# np.float64(0.5)

# %% [markdown]
# Результат тестирования нашей модели на тествой выборке был лучше, чем результат константной модели

# %% [markdown]
# ## Выводы

# %% [markdown]
# SVC с полиноминальным ядром в степени 2 оказалась лучше всех, так как она лучше остальных находит закономерности в данных, в которых есть нелинейные зависимости

# %% [markdown]
# # Общий вывод

# %% [markdown]
# Решенные задачи:
# - Построить модель, которая сможет предсказать уровень удовлетворённости сотрудника на основе данных заказчика.
# - Построить модель, которая сможет на основе данных заказчика предсказать то, что сотрудник уволится из компании
#
# Ход работы:
# - Загружены и предобработаны данные. В ходе предобработки данных были исключены дубликаты, а также изменены некоторые наименования в категориальных данных.
# - Проведен исследовательский анализ данных. В ходе исследовательского анализа данных не выявлено выбросов и аномалий. Все признаки, кроме зарплаты и целевого, являются категориальными.
# - Был составлен портрет "Уволившегося сотрудника", удовлетворенность рабочим процессом, зарплата влияют на потенциальное решение об увольнении со стороны сотрудника
# - В пайплане данные были подготовлены:
#     - OrdinalEncoder для level, workload, employment_years, supervisor_evaluation
#
#     - OneHotEncoder для dept, last_year_promo, last_year_violations
#
#     - StandardScaler и MinMaxScaler перебраны при помощи кросс-валидации для количественных признаков.
# - Обучены DecisionTreeRegressor и LinearRegression для задачи регрессии. Лучшей моделью оказалась DecisionTreeRegressor с параметрами models__max_depth = 11, models__max_features = 8.
# - Обучено 7 типов моделей с перебором гиперпараметров для задачи классификации, SVC с полиноминальным ядром в степени 2 оказалась лучше всех.
#
# В данной ситуации бизнесу стоит обратить внимание на заработные платы сотрудников, которые не удовлетворены рабочим процессом (если это соответствует интересам компании), а также обратить внимание именно на junior - они чаще всего покидают компанию.
